# %% [markdown]
# # *** Unit 3 Lecture***

# %% [markdown]
# # ***This script will be a part of HW #2 Functions and Modules***

# %% [markdown]
# Slide 1: Introduction to Functions

# %%
print("Functions allow us to reuse code and make our programs more modular.")
# Out:
# Functions allow us to reuse code and make our programs more modular.

# %% [markdown]
# Slide 2-3: Defining and Calling a Simple Function

# %%
def greet():
    print("Hello! Welcome to Python Functions.")

# Run the function
greet()
# Out:
# Hello! Welcome to Python Functions.

# %% [markdown]
# Challenge 1

# %%
# Vikram Nadathur May 28th 2026
# Challenge 1: Define a function that prints "Python is fun!"
# Complete the code below
def python_fun():
    print("Python is fun!")
python_fun()
# Out:
# Python is fun!

# %% [markdown]
# Slides 6-7: Function with Parameters

# %%
def personalized_greeting(name):
    print(f"Hello, {name}! Welcome to Python Functions.")

# Run the function
personalized_greeting("Alice")
# Out:
# Hello, Alice! Welcome to Python Functions.

# %% [markdown]
# Challenge 2: Define a function that takes two arguments and prints their sum

# %%
# Vikram Nadathur May 28th 2026
# Complete the code below
def print_sum(a, b):
    return(a+b)
print_sum(3,5)
# Out:
# 8

# %% [markdown]
# Slide 7: Returning Values from Functions

# %%
def add(a, b):
    return a + b

# Run the function and print the result
result = add(3, 5)
print(f"The sum is: {result}")
# Out:
# The sum is: 8

# %% [markdown]
# Challenge 3: Define a function that returns the product of two numbers

# %%
# Vikram Nadathur May 28th 2026
# Complete the code below
def multiply(a, b):
    return(a*b)
multiply(3,5)
# Out:
# 15

# %% [markdown]
# Slide 8-9: Local and Global Variables

# %%
# Example 4: Local Variable
def local_variable_example():
    local_var = 10
    print(f"Local variable: {local_var}")

# Run the function
local_variable_example()
# Out:
# Local variable: 10

# %% [markdown]
# Challenge 4: Define a function that declares a local variable and prints it

# %%
# Vikram Nadathur May 28th 2026
# Complete the code below
def print_local():
    local_var = 10
    print(f"Local variable: {local_var}")
print_local()
# Out:
# Local variable: 10

# %% [markdown]
# Slide 10: Global Variable

# %%
global_var = 20

def global_variable_example():
    print(f"Global variable: {global_var}")

# Run the function
global_variable_example()
# Out:
# Global variable: 20

# %% [markdown]
# Challenge 5: Modify the global variable within a function

# %%
# Vikram Nadathur May 28th 2026
# Complete the code below
def modify_global():
    global global_var
    global_var = 30
modify_global()
print(global_var)
# Out:
# 30

# %% [markdown]
# Slide 11-13: Passing Arguments to Functions

# %%
# Example 6: Passing Multiple Arguments
def print_full_name(first_name, last_name):
    print(f"Full name: {first_name} {last_name}")

# Run the function
print_full_name("John", "Doe")
# Out:
# Full name: John Doe

# %% [markdown]
# Challenge 6: Define a function that takes three arguments and prints them

# %%
# Vikram Nadathur May 28th 2026
# Complete the code below
def print_three(a, b, c):
    print(a, b, c)

# Example call
print_three(1, 2, 3)
# Out:
# 1 2 3

# %% [markdown]
# Slide 14-15: Keyword Arguments

# %%
def describe_pet(animal_type, pet_name):
    print(f"\nI have a {animal_type}.")
    print(f"My {animal_type}'s name is {pet_name}.")

# Run the function using keyword arguments
describe_pet(animal_type='hamster', pet_name='Harry')
# Out:
# I have a hamster.
# My hamster's name is Harry.

# %% [markdown]
# Challenge 7: Define a function with keyword arguments and call it

# %%
# Vikram Nadathur May 28th 2026
# Complete the code below
def show_vehicle(type, brand):
    print(f"My vehicle is a {brand} {type}.")

# Example calls using keyword arguments
show_vehicle(type='car', brand='Toyota')
show_vehicle(brand='Tesla', type='truck')
# Out:
# My vehicle is a Toyota car.
# My vehicle is a Tesla truck.

# %% [markdown]
# Slide 10-12: Default Argument Values

# %%
# Example 8: Default Argument
def print_greeting(name, greeting="Hello"):
    print(f"{greeting}, {name}!")

# Run the function with and without the default argument
print_greeting("Alice")
print_greeting("Bob", "Hi")
# Out:
# Hello, Alice!
# Hi, Bob!

# %% [markdown]
# Challenge 8: Define a function with a default argument and call it

# %%
# Vikram Nadathur May 28th 2026
# Complete the code below

def introduce(name, age=25):
    print(f"My name is {name} and I am {age} years old.")

# Example calls
introduce("Alice")
introduce("Bob", 30)
# Out:
# My name is Alice and I am 25 years old.
# My name is Bob and I am 30 years old.

# %% [markdown]
# Slide 13: Value-Returning Functions

# %%
# Example 9: Value-Returning Function
def square(number):
    return number * number

# Run the function and print the result
result = square(4)
print(f"The square of 4 is: {result}")
# Out:
# The square of 4 is: 16

# %% [markdown]
# Challenge 9: Define a function that returns the cube of a number

# %%
# Vikram Nadathur May 28th 2026
# Complete the code below

def cube(number):
    return number * number * number

# Example call
print(cube(3))
# Out:
# 27

# %% [markdown]
# Slides 14-16: The random and math Modules

# %%
import random
# Generate a random float in the range [0.0, 1.0)
number = random.random()
print("Random float between 0.0 and 1.0:", number)
# Out:
# Random float between 0.0 and 1.0: 0.30036210324236257

# %%
import random
# Generate a random integer between 1 and 100
number = random.randint(1, 100)
print("Random number between 1 and 100:", number)
# Out:
# Random number between 1 and 100: 37

# %%
import math

# Example 10: Using the math Module
def calculate_circle_area(radius):
    return math.pi * radius * radius

# Run the function and print the result
area = calculate_circle_area(5)
print(f"The area of the circle is: {area:.2f}")
# Out:
# The area of the circle is: 78.54

# %% [markdown]
# Challenge 10: Define a function that uses the math module to calculate the square root of a number

# %%
# Vikram Nadathur May 28th 2026
# Complete the code below

import math

def calculate_sqrt(number):
    return math.sqrt(number)

# Example call
print(calculate_sqrt(16))
# Out:
# 4.0

# %% [markdown]
# Slide 20-21: Storing Functions in Modules

# %%
# Vikram Nadathur May 28th 2026
# Complete the code below be creating with your functions

# %%writefile custom_module.py
def function_one():
    print("Function One")

def function_two():
    print("Function Two")
# Out:
# Writing custom_module.py

# %% [markdown]
# uncommend 2 lines below

# %%
# %%writefile my_module.py
def my_function():
     print("Hello from my_module!")
# Out:
# Writing my_module.py

# %%
from my_module import my_function
my_function()
# Out:
# Hello from my_module!

# %% [markdown]
# Challenge 11: Create your own module with at least two functions and import it here

# %%
# Vikram Nadathur May 28th 2026
# Complete the code below be creating with your functions

# %%writefile custom_module.py
def function_one():
    print("Function One")

def function_two():
    print("Function Two")
# Out:
# Overwriting custom_module.py

# %%
from custom_module import function_one, function_two

function_one()
function_two()
# Out:
# Function One
# Function Two

# %%
# Example 14: Generating Random Numbers
import random

def roll_die():
    return random.randint(1, 6)

# Run the function and print the result
die_roll = roll_die()
print(f"Rolled a die: {die_roll}")
# Out:
# Rolled a die: 1

# %% [markdown]
# Challenge 13: Define a function that generates a random float between two numbers

# %%
# Vikram Nadathur May 28th 2026
# Complete the code below

import random

def random_float(min_value, max_value):
    return random.uniform(min_value, max_value)

# Example call
print(random_float(1.5, 4.2))
# Out:
# 3.0307681949089726

# %%
# Example 15: Returning Multiple Values
def min_max(numbers):
    return min(numbers), max(numbers)

# Run the function and print the result
min_val, max_val = min_max([1, 2, 3, 4, 5])
print(f"Min: {min_val}, Max: {max_val}")
# Out:
# Min: 1, Max: 5

# %% [markdown]
# Challenge 14: Define a function that returns the sum, difference, and product of two numbers

# %%
# Vikram Nadathur May 28th 2026
# Complete the code below

def calculate(a, b):
    total = a + b
    difference = a - b
    product = a * b
    return total, difference, product

# Example call
s, d, p = calculate(5, 3)
print("Sum:", s, "Difference:", d, "Product:", p)
# Out:
# Sum: 8 Difference: 2 Product: 15

# %% [markdown]
# Returning None from a Function

# %%
def divide(num1, num2):
    if num2 == 0:
        return None
    else:
        return num1 / num2

# Run the function and handle the result
result = divide(10, 0)
if result is None:
    print("Cannot divide by zero!")
else:
    print(f"Result: {result}")
# Out:
# Cannot divide by zero!

# %% [markdown]
# Challenge 15: Define a function that returns None if a number is negative

# %%
# Vikram Nadathur May 28th 2026
# Complete the code below

def check_positive(number):
    if number < 0:
        return None
    else:
        return number

# Example calls
print(check_positive(10))   # 10
print(check_positive(-5))   # None
# Out:
# 10
# None

# %% [markdown]
# Conditional Execution of the main Function

# %%
def main():
    print("This is the main function.")

def secondary_function():
    print("This is a secondary function.")

if __name__ == '__main__':
    main()
# Out:
# This is the main function.

# %% [markdown]
# Challenge 16: Define two functions and conditionally execute one based on a variable value

# %%
# Vikram Nadathur May 28th 2026
# Complete the code below

def function_one():
    print("Function one is running.")

def function_two():
    print("Function two is running.")

# Choose which function to run
run_first = True  # change to False to run function_two instead

if run_first:
    function_one()
else:
    function_two()
# Out:
# Function one is running.

# %%
# %%writefile nasa.py
# apod.py
import requests
from IPython.display import display, Image

def get_apod(api_key):
    response = requests.get(f'https://api.nasa.gov/planetary/apod?api_key={api_key}')
    if response.status_code == 200:
        data = response.json()
        return data['title'], data['url'], data['explanation']
    else:
        return "Could not fetch APOD data", "", ""

def display_apod(api_key):
    title, url, explanation = get_apod(api_key)
    if title == "Could not fetch APOD data":
        print(title)
    else:
        print(f"Title: {title}\nURL: {url}\nExplanation: {explanation}")
        display(Image(url=url, embed=True))
# Out:
# Writing nasa.py

# %%
# Import the apod module
import nasa

# Use the DEMO_KEY provided by NASA
api_key = "DEMO_KEY"

# Call the function to display APOD data and image
nasa.display_apod(api_key)
# Out:
# Title: NGC 1514: The Crystal Ball Nebula
# URL: https://apod.nasa.gov/apod/image/2605/noirlab2613a.jpg
# Explanation: What do you see in this crystal ball?   The featured image shows NGC 1514, known as the Crystal Ball Nebula, observed by the Gemini North telescope on Maunakea, in Hawai'i.   NGC 1514 is 1,500 light-years away and was discovered by William Herschel in 1790.   This planetary nebula is formed when a star becomes a red giant and ejects its outer gas layers.   The ejected shell of gas is heated up by the core of the star to temperatures hotter than the surface of our Sun: that makes the gas shine, creating beautiful images like this one.       The slightly asymmetrical shape of the Crystal Ball Nebula reveals a secret: the bright star in the center has a companion.   As the two stars orbit each other with a period of about nine years, they shape the gas around them.   In about 10,000 - 25,000 years the nebula will be dissipated by their stellar winds.

# %% [markdown]
# More on Modules in Class Lab
